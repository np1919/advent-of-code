# %%
# day 3 part 1

with open('puzzle_input.txt', 'r') as f:
    data = [x.strip('\n').strip(' ') for x in f.readlines()]

import string
import re
# all symbols except for `.`
symbols = [x for x in string.punctuation]
symbols.remove('.')

class Node:
    def __init__(self, rownum, colnum, value
                #  , prev_node
                 ):
        self.rownum = rownum
        self.colnum = colnum
        self.value = value
        # self.prev_node = prev_node
        self.connected = False
        pass
    
    def __repr__(self):
        return f"{self.value} at {self.rownum, self.colnum}"


all_nodes = []

for rownum, row in enumerate(data):
    thisrow = []
    current = None
    for colnum, column in enumerate(row):
        current = Node(rownum, colnum, data[rownum][colnum]
                    #    , prev_node=current
                       )
        thisrow.append(current)
    all_nodes.append(thisrow)

all_symbols = []

for rownum, row in enumerate(all_nodes):
    for colnum, cell in enumerate(row):
        if cell.value in symbols:
            cell.connected=True
            all_symbols.append(cell)

            ## add the connected indexes
            for i in range(cell.rownum-1, cell.rownum+2):
                for j in range(cell.colnum-1, cell.colnum+2):
                    try:
                        all_nodes[i][j].connected = True
                    except:
                        print('error') # no symbols are out of bounds?? crazy
                        print('out of bounds for row {i} column {j}')
# all_nodes.__len__(), [x.__len__() for x in all_nodes]

# for row in all_nodes:
#     print([True if x.connected == True else None for x in row])

indexes_of_connected_cells = set()

for row in all_nodes:
    for cell in row:
        if cell.connected == True:
            indexes_of_connected_cells.add((cell.rownum, cell.colnum))
            print(f'cell at {cell.rownum},{cell.colnum} is connected')
# len(indexes_of_connected_cells)/(140* 140)
connected_parts = []
unconnected_parts = []
for rownum, row in enumerate(data):
    matches = re.finditer('\d+', row)

    for m in matches:
        print(m.group())

        for col_index in range(m.start(), m.end()):
            if (rownum, col_index) in indexes_of_connected_cells:
                connected_parts.append(m.group())
                print(f'continuing from {m.group()}')
                break
            # else:
            #     print(f"index {rownum, col_index} not connected")
        
sum(int(x) for x in connected_parts)
# 546563 is the correct answer
# Out:
# cell at 0,37 is connected
# cell at 0,38 is connected
# cell at 0,39 is connected
# cell at 0,73 is connected
# cell at 0,74 is connected
# cell at 0,75 is connected
# cell at 0,83 is connected
# cell at 0,84 is connected
# cell at 0,85 is connected
# cell at 0,120 is connected
# cell at 0,121 is connected
# cell at 0,122 is connected
# cell at 1,37 is connected
# cell at 1,38 is connected
# cell at 1,39 is connected
# cell at 1,46 is connected
# cell at 1,47 is connected
# cell at 1,48 is connected
# cell at 1,73 is connected
# cell at 1,74 is connected
# cell at 1,75 is connected
# cell at 1,83 is connected
# cell at 1,84 is connected
# cell at 1,85 is connected
# cell at 1,94 is connected
# cell at 1,95 is connected
# cell at 1,96 is connected
# cell at 1,107 is connected
# cell at 1,108 is connected
# cell at 1,109 is connected
# cell at 1,120 is connected
# cell at 1,121 is connected
# cell at 1,122 is connected
# cell at 1,125 is connected
# cell at 1,126 is connected
# cell at 1,127 is connected
# cell at 2,37 is connected
# cell at 2,38 is connected
# cell at 2,39 is connected
# cell at 2,46 is connected
# cell at 2,47 is connected
# cell at 2,48 is connected
# cell at 2,73 is connected
# cell at 2,74 is connected
# cell at 2,75 is connected
# cell at 2,82 is connected
# cell at 2,83 is connected
# cell at 2,84 is connected
# cell at 2,85 is connected
# cell at 2,94 is connected
# cell at 2,95 is connected
# cell at 2,96 is connected
# cell at 2,107 is connected
# cell at 2,108 is connected
# cell at 2,109 is connected
# cell at 2,117 is connected
# cell at 2,118 is connected
# cell at 2,119 is connected
# cell at 2,120 is connected
# cell at 2,121 is connected
# cell at 2,122 is connected
# cell at 2,123 is connected
# cell at 2,124 is connected
# cell at 2,125 is connected
# cell at 2,126 is connected
# cell at 2,127 is connected
# cell at 2,128 is connected
# cell at 2,129 is connected
# cell at 2,131 is connected
# cell at 2,132 is connected
# cell at 2,133 is connected
# cell at 3,9 is connected
# cell at 3,10 is connected
# cell at 3,11 is connected
# cell at 3,20 is connected
# cell at 3,21 is connected
# cell at 3,22 is connected
# cell at 3,46 is connected
# cell at 3,47 is connected
# cell at 3,48 is connected
# cell at 3,51 is connected
# cell at 3,52 is connected
# cell at 3,53 is connected
# cell at 3,82 is connected
# cell at 3,83 is connected
# cell at 3,84 is connected
# cell at 3,94 is connected
# cell at 3,95 is connected
# cell at 3,96 is connected
# cell at 3,99 is connected
# cell at 3,100 is connected
# cell at 3,101 is connected
# cell at 3,107 is connected
# cell at 3,108 is connected
# cell at 3,109 is connected
# cell at 3,117 is connected
# cell at 3,118 is connected
# cell at 3,119 is connected
# cell at 3,122 is connected
# cell at 3,123 is connected
# cell at 3,124 is connected
# cell at 3,125 is connected
# cell at 3,126 is connected
# cell at 3,127 is connected
# cell at 3,128 is connected
# cell at 3,129 is connected
# cell at 3,131 is connected
# cell at 3,132 is connected
# cell at 3,133 is connected
# cell at 3,134 is connected
# cell at 3,135 is connected
# cell at 3,136 is connected
# cell at 4,9 is connected
# cell at 4,10 is connected
# cell at 4,11 is connected
# cell at 4,20 is connected
# cell at 4,21 is connected
# cell at 4,22 is connected
# cell at 4,32 is connected
# cell at 4,33 is connected
# cell at 4,34 is connected
# cell at 4,41 is connected
# cell at 4,42 is connected
# cell at 4,43 is connected
# cell at 4,51 is connected
# cell at 4,52 is connected
# cell at 4,53 is connected
# cell at 4,65 is connected
# cell at 4,66 is connected
# cell at 4,67 is connected
# cell at 4,81 is connected
# cell at 4,82 is connected
# cell at 4,83 is connected
# cell at 4,84 is connected
# cell at 4,99 is connected
# cell at 4,100 is connected
# cell at 4,101 is connected
# cell at 4,103 is connected
# cell at 4,104 is connected
# cell at 4,105 is connected
# cell at 4,117 is connected
# cell at 4,118 is connected
# cell at 4,119 is connected
# cell at 4,122 is connected
# cell at 4,123 is connected
# cell at 4,124 is connected
# cell at 4,127 is connected
# cell at 4,128 is connected
# cell at 4,129 is connected
# cell at 4,131 is connected
# cell at 4,132 is connected
# cell at 4,133 is connected
# cell at 4,134 is connected
# cell at 4,135 is connected
# cell at 4,136 is connected
# cell at 5,9 is connected
# cell at 5,10 is connected
# cell at 5,11 is connected
# cell at 5,20 is connected
# cell at 5,21 is connected
# cell at 5,22 is connected
# cell at 5,32 is connected
# cell at 5,33 is connected
# cell at 5,34 is connected
# cell at 5,41 is connected
# cell at 5,42 is connected
# cell at 5,43 is connected
# cell at 5,50 is connected
# cell at 5,51 is connected
# cell at 5,52 is connected
# cell at 5,53 is connected
# cell at 5,65 is connected
# cell at 5,66 is connected
# cell at 5,67 is connected
# cell at 5,74 is connected
# cell at 5,75 is connected
# cell at 5,76 is connected
# cell at 5,81 is connected
# cell at 5,82 is connected
# cell at 5,83 is connected
# cell at 5,91 is connected
# cell at 5,92 is connected
# cell at 5,93 is connected
# cell at 5,96 is connected
# cell at 5,97 is connected
# cell at 5,98 is connected
# cell at 5,99 is connected
# cell at 5,100 is connected
# cell at 5,101 is connected
# cell at 5,103 is connected
# cell at 5,104 is connected
# cell at 5,105 is connected
# cell at 5,109 is connected
# cell at 5,110 is connected
# cell at 5,111 is connected
# cell at 5,114 is connected
# cell at 5,115 is connected
# cell at 5,116 is connected
# cell at 5,124 is connected
# cell at 5,125 is connected
# cell at 5,126 is connected
# cell at 5,134 is connected
# cell at 5,135 is connected
# cell at 5,136 is connected
# cell at 6,32 is connected
# cell at 6,33 is connected
# cell at 6,34 is connected
# cell at 6,41 is connected
# cell at 6,42 is connected
# cell at 6,43 is connected
# cell at 6,50 is connected
# cell at 6,51 is connected
# cell at 6,52 is connected
# cell at 6,57 is connected
# cell at 6,58 is connected
# cell at 6,59 is connected
# cell at 6,65 is connected
# cell at 6,66 is connected
# cell at 6,67 is connected
# cell at 6,69 is connected
# cell at 6,70 is connected
# cell at 6,71 is connected
# cell at 6,74 is connected
# cell at 6,75 is connected
# cell at 6,76 is connected
# cell at 6,77 is connected
# cell at 6,78 is connected
# cell at 6,81 is connected
# cell at 6,82 is connected
# cell at 6,83 is connected
# cell at 6,91 is connected
# cell at 6,92 is connected
# cell at 6,93 is connected
# cell at 6,96 is connected
# cell at 6,97 is connected
# cell at 6,98 is connected
# cell at 6,103 is connected
# cell at 6,104 is connected
# cell at 6,105 is connected
# cell at 6,109 is connected
# cell at 6,110 is connected
# cell at 6,111 is connected
# cell at 6,114 is connected
# cell at 6,115 is connected
# cell at 6,116 is connected
# cell at 6,118 is connected
# cell at 6,119 is connected
# cell at 6,120 is connected
# cell at 6,124 is connected
# cell at 6,125 is connected
# cell at 6,126 is connected
# cell at 7,26 is connected
# cell at 7,27 is connected
# cell at 7,28 is connected
# cell at 7,31 is connected
# cell at 7,32 is connected
# cell at 7,33 is connected
# cell at 7,36 is connected
# cell at 7,37 is connected
# cell at 7,38 is connected
# cell at 7,47 is connected
# cell at 7,48 is connected
# cell at 7,49 is connected
# cell at 7,50 is connected
# cell at 7,51 is connected
# cell at 7,52 is connected
# cell at 7,57 is connected
# cell at 7,58 is connected
# cell at 7,59 is connected
# cell at 7,64 is connected
# cell at 7,65 is connected
# cell at 7,66 is connected
# cell at 7,69 is connected
# cell at 7,70 is connected
# cell at 7,71 is connected
# cell at 7,74 is connected
# cell at 7,75 is connected
# cell at 7,76 is connected
# cell at 7,77 is connected
# cell at 7,78 is connected
# cell at 7,91 is connected
# cell at 7,92 is connected
# cell at 7,93 is connected
# cell at 7,96 is connected
# cell at 7,97 is connected
# cell at 7,98 is connected
# cell at 7,109 is connected
# cell at 7,110 is connected
# cell at 7,111 is connected
# cell at 7,114 is connected
# cell at 7,115 is connected
# cell at 7,116 is connected
# cell at 7,118 is connected
# cell at 7,119 is connected
# cell at 7,120 is connected
# cell at 7,124 is connected
# cell at 7,125 is connected
# cell at 7,126 is connected
# cell at 7,127 is connected
# cell at 7,133 is connected
# cell at 7,134 is connected
# cell at 7,135 is connected
# cell at 8,6 is connected
# cell at 8,7 is connected
# cell at 8,8 is connected
# cell at 8,26 is connected
# cell at 8,27 is connected
# cell at 8,28 is connected
# cell at 8,31 is connected
# cell at 8,32 is connected
# cell at 8,33 is connected
# cell at 8,36 is connected
# cell at 8,37 is connected
# cell at 8,38 is connected
# cell at 8,47 is connected
# cell at 8,48 is connected
# cell at 8,49 is connected
# cell at 8,53 is connected
# cell at 8,54 is connected
# cell at 8,55 is connected
# cell at 8,57 is connected
# cell at 8,58 is connected
# cell at 8,59 is connected
# cell at 8,64 is connected
# cell at 8,65 is connected
# cell at 8,66 is connected
# cell at 8,69 is connected
# cell at 8,70 is connected
# cell at 8,71 is connected
# cell at 8,72 is connected
# cell at 8,73 is connected
# cell at 8,74 is connected
# cell at 8,76 is connected
# cell at 8,77 is connected
# cell at 8,78 is connected
# cell at 8,109 is connected
# cell at 8,110 is connected
# cell at 8,111 is connected
# cell at 8,118 is connected
# cell at 8,119 is connected
# cell at 8,120 is connected
# cell at 8,125 is connected
# cell at 8,126 is connected
# cell at 8,127 is connected
# cell at 8,133 is connected
# cell at 8,134 is connected
# cell at 8,135 is connected
# cell at 9,6 is connected
# cell at 9,7 is connected
# cell at 9,8 is connected
# cell at 9,15 is connected
# cell at 9,16 is connected
# cell at 9,17 is connected
# cell at 9,26 is connected
# cell at 9,27 is connected
# cell at 9,28 is connected
# cell at 9,31 is connected
# cell at 9,32 is connected
# cell at 9,33 is connected
# cell at 9,36 is connected
# cell at 9,37 is connected
# cell at 9,38 is connected
# cell at 9,39 is connected
# cell at 9,40 is connected
# cell at 9,41 is connected
# cell at 9,47 is connected
# cell at 9,48 is connected
# cell at 9,49 is connected
# cell at 9,53 is connected
# cell at 9,54 is connected
# cell at 9,55 is connected
# cell at 9,64 is connected
# cell at 9,65 is connected
# cell at 9,66 is connected
# cell at 9,72 is connected
# cell at 9,73 is connected
# cell at 9,74 is connected
# cell at 9,85 is connected
# cell at 9,86 is connected
# cell at 9,87 is connected
# cell at 9,92 is connected
# cell at 9,93 is connected
# cell at 9,94 is connected
# cell at 9,96 is connected
# cell at 9,97 is connected
# cell at 9,98 is connected
# cell at 9,102 is connected
# cell at 9,103 is connected
# cell at 9,104 is connected
# cell at 9,109 is connected
# cell at 9,110 is connected
# cell at 9,111 is connected
# cell at 9,114 is connected
# cell at 9,115 is connected
# cell at 9,116 is connected
# cell at 9,118 is connected
# cell at 9,119 is connected
# cell at 9,120 is connected
# cell at 9,125 is connected
# cell at 9,126 is connected
# cell at 9,127 is connected
# cell at 9,133 is connected
# cell at 9,134 is connected
# cell at 9,135 is connected
# cell at 10,6 is connected
# cell at 10,7 is connected
# cell at 10,8 is connected
# cell at 10,10 is connected
# cell at 10,11 is connected
# cell at 10,12 is connected
# cell at 10,15 is connected
# cell at 10,16 is connected
# cell at 10,17 is connected
# cell at 10,21 is connected
# cell at 10,22 is connected
# cell at 10,23 is connected
# cell at 10,39 is connected
# cell at 10,40 is connected
# cell at 10,41 is connected
# cell at 10,47 is connected
# cell at 10,48 is connected
# cell at 10,49 is connected
# cell at 10,53 is connected
# cell at 10,54 is connected
# cell at 10,55 is connected
# cell at 10,59 is connected
# cell at 10,60 is connected
# cell at 10,61 is connected
# cell at 10,64 is connected
# cell at 10,65 is connected
# cell at 10,66 is connected
# cell at 10,72 is connected
# cell at 10,73 is connected
# cell at 10,74 is connected
# cell at 10,85 is connected
# cell at 10,86 is connected
# cell at 10,87 is connected
# cell at 10,92 is connected
# cell at 10,93 is connected
# cell at 10,94 is connected
# cell at 10,96 is connected
# cell at 10,97 is connected
# cell at 10,98 is connected
# cell at 10,102 is connected
# cell at 10,103 is connected
# cell at 10,104 is connected
# cell at 10,109 is connected
# cell at 10,110 is connected
# cell at 10,111 is connected
# cell at 10,114 is connected
# cell at 10,115 is connected
# cell at 10,116 is connected
# cell at 10,118 is connected
# cell at 10,119 is connected
# cell at 10,120 is connected
# cell at 10,121 is connected
# cell at 10,122 is connected
# cell at 10,123 is connected
# cell at 10,127 is connected
# cell at 10,128 is connected
# cell at 10,129 is connected
# cell at 11,10 is connected
# cell at 11,11 is connected
# cell at 11,12 is connected
# cell at 11,15 is connected
# cell at 11,16 is connected
# cell at 11,17 is connected
# cell at 11,21 is connected
# cell at 11,22 is connected
# cell at 11,23 is connected
# cell at 11,33 is connected
# cell at 11,34 is connected
# cell at 11,35 is connected
# cell at 11,39 is connected
# cell at 11,40 is connected
# cell at 11,41 is connected
# cell at 11,47 is connected
# cell at 11,48 is connected
# cell at 11,49 is connected
# cell at 11,59 is connected
# cell at 11,60 is connected
# cell at 11,61 is connected
# cell at 11,64 is connected
# cell at 11,65 is connected
# cell at 11,66 is connected
# cell at 11,67 is connected
# cell at 11,68 is connected
# cell at 11,69 is connected
# cell at 11,85 is connected
# cell at 11,86 is connected
# cell at 11,87 is connected
# cell at 11,92 is connected
# cell at 11,93 is connected
# cell at 11,94 is connected
# cell at 11,96 is connected
# cell at 11,97 is connected
# cell at 11,98 is connected
# cell at 11,102 is connected
# cell at 11,103 is connected
# cell at 11,104 is connected
# cell at 11,105 is connected
# cell at 11,114 is connected
# cell at 11,115 is connected
# cell at 11,116 is connected
# cell at 11,118 is connected
# cell at 11,119 is connected
# cell at 11,120 is connected
# cell at 11,121 is connected
# cell at 11,122 is connected
# cell at 11,123 is connected
# cell at 11,127 is connected
# cell at 11,128 is connected
# cell at 11,129 is connected
# cell at 11,133 is connected
# cell at 11,134 is connected
# cell at 11,135 is connected
# cell at 12,4 is connected
# cell at 12,5 is connected
# cell at 12,6 is connected
# cell at 12,10 is connected
# cell at 12,11 is connected
# cell at 12,12 is connected
# cell at 12,21 is connected
# cell at 12,22 is connected
# cell at 12,23 is connected
# cell at 12,33 is connected
# cell at 12,34 is connected
# cell at 12,35 is connected
# cell at 12,43 is connected
# cell at 12,44 is connected
# cell at 12,45 is connected
# cell at 12,47 is connected
# cell at 12,48 is connected
# cell at 12,49 is connected
# cell at 12,52 is connected
# cell at 12,53 is connected
# cell at 12,54 is connected
# cell at 12,59 is connected
# cell at 12,60 is connected
# cell at 12,61 is connected
# cell at 12,64 is connected
# cell at 12,65 is connected
# cell at 12,66 is connected
# cell at 12,67 is connected
# cell at 12,68 is connected
# cell at 12,69 is connected
# cell at 12,80 is connected
# cell at 12,81 is connected
# cell at 12,82 is connected
# cell at 12,103 is connected
# cell at 12,104 is connected
# cell at 12,105 is connected
# cell at 12,106 is connected
# cell at 12,107 is connected
# cell at 12,108 is connected
# cell at 12,116 is connected
# cell at 12,117 is connected
# cell at 12,118 is connected
# cell at 12,121 is connected
# cell at 12,122 is connected
# cell at 12,123 is connected
# cell at 12,127 is connected
# cell at 12,128 is connected
# cell at 12,129 is connected
# cell at 12,133 is connected
# cell at 12,134 is connected
# cell at 12,135 is connected
# cell at 13,4 is connected
# cell at 13,5 is connected
# cell at 13,6 is connected
# cell at 13,33 is connected
# cell at 13,34 is connected
# cell at 13,35 is connected
# cell at 13,43 is connected
# cell at 13,44 is connected
# cell at 13,45 is connected
# cell at 13,46 is connected
# cell at 13,47 is connected
# cell at 13,48 is connected
# cell at 13,52 is connected
# cell at 13,53 is connected
# cell at 13,54 is connected
# cell at 13,67 is connected
# cell at 13,68 is connected
# cell at 13,69 is connected
# cell at 13,73 is connected
# cell at 13,74 is connected
# cell at 13,75 is connected
# cell at 13,80 is connected
# cell at 13,81 is connected
# cell at 13,82 is connected
# cell at 13,85 is connected
# cell at 13,86 is connected
# cell at 13,87 is connected
# cell at 13,94 is connected
# cell at 13,95 is connected
# cell at 13,96 is connected
# cell at 13,103 is connected
# cell at 13,104 is connected
# cell at 13,105 is connected
# cell at 13,106 is connected
# cell at 13,107 is connected
# cell at 13,108 is connected
# cell at 13,116 is connected
# cell at 13,117 is connected
# cell at 13,118 is connected
# cell at 13,133 is connected
# cell at 13,134 is connected
# cell at 13,135 is connected
# cell at 14,4 is connected
# cell at 14,5 is connected
# cell at 14,6 is connected
# cell at 14,43 is connected
# cell at 14,44 is connected
# cell at 14,45 is connected
# cell at 14,46 is connected
# cell at 14,47 is connected
# cell at 14,48 is connected
# cell at 14,52 is connected
# cell at 14,53 is connected
# cell at 14,54 is connected
# cell at 14,59 is connected
# cell at 14,60 is connected
# cell at 14,61 is connected
# cell at 14,63 is connected
# cell at 14,64 is connected
# cell at 14,65 is connected
# cell at 14,68 is connected
# cell at 14,69 is connected
# cell at 14,70 is connected
# cell at 14,73 is connected
# cell at 14,74 is connected
# cell at 14,75 is connected
# cell at 14,80 is connected
# cell at 14,81 is connected
# cell at 14,82 is connected
# cell at 14,85 is connected
# cell at 14,86 is connected
# cell at 14,87 is connected
# cell at 14,94 is connected
# cell at 14,95 is connected
# cell at 14,96 is connected
# cell at 14,106 is connected
# cell at 14,107 is connected
# cell at 14,108 is connected
# cell at 14,109 is connected
# cell at 14,110 is connected
# cell at 14,116 is connected
# cell at 14,117 is connected
# cell at 14,118 is connected
# cell at 14,122 is connected
# cell at 14,123 is connected
# cell at 14,124 is connected
# cell at 14,125 is connected
# cell at 14,126 is connected
# cell at 14,127 is connected
# cell at 14,135 is connected
# cell at 14,136 is connected
# cell at 14,137 is connected
# cell at 15,26 is connected
# cell at 15,27 is connected
# cell at 15,28 is connected
# cell at 15,32 is connected
# cell at 15,33 is connected
# cell at 15,34 is connected
# cell at 15,46 is connected
# cell at 15,47 is connected
# cell at 15,48 is connected
# cell at 15,49 is connected
# cell at 15,50 is connected
# cell at 15,51 is connected
# cell at 15,59 is connected
# cell at 15,60 is connected
# cell at 15,61 is connected
# cell at 15,63 is connected
# cell at 15,64 is connected
# cell at 15,65 is connected
# cell at 15,68 is connected
# cell at 15,69 is connected
# cell at 15,70 is connected
# cell at 15,73 is connected
# cell at 15,74 is connected
# cell at 15,75 is connected
# cell at 15,76 is connected
# cell at 15,81 is connected
# cell at 15,82 is connected
# cell at 15,83 is connected
# cell at 15,85 is connected
# cell at 15,86 is connected
# cell at 15,87 is connected
# cell at 15,94 is connected
# cell at 15,95 is connected
# cell at 15,96 is connected
# cell at 15,108 is connected
# cell at 15,109 is connected
# cell at 15,110 is connected
# cell at 15,122 is connected
# cell at 15,123 is connected
# cell at 15,124 is connected
# cell at 15,125 is connected
# cell at 15,126 is connected
# cell at 15,127 is connected
# cell at 15,135 is connected
# cell at 15,136 is connected
# cell at 15,137 is connected
# cell at 16,18 is connected
# cell at 16,19 is connected
# cell at 16,20 is connected
# cell at 16,26 is connected
# cell at 16,27 is connected
# cell at 16,28 is connected
# cell at 16,32 is connected
# cell at 16,33 is connected
# cell at 16,34 is connected
# cell at 16,49 is connected
# cell at 16,50 is connected
# cell at 16,51 is connected
# cell at 16,59 is connected
# cell at 16,60 is connected
# cell at 16,61 is connected
# cell at 16,63 is connected
# cell at 16,64 is connected
# cell at 16,65 is connected
# cell at 16,68 is connected
# cell at 16,69 is connected
# cell at 16,70 is connected
# cell at 16,74 is connected
# cell at 16,75 is connected
# cell at 16,76 is connected
# cell at 16,81 is connected
# cell at 16,82 is connected
# cell at 16,83 is connected
# cell at 16,108 is connected
# cell at 16,109 is connected
# cell at 16,110 is connected
# cell at 16,117 is connected
# cell at 16,118 is connected
# cell at 16,119 is connected
# cell at 16,122 is connected
# cell at 16,123 is connected
# cell at 16,124 is connected
# cell at 16,125 is connected
# cell at 16,126 is connected
# cell at 16,127 is connected
# cell at 16,128 is connected
# cell at 16,129 is connected
# cell at 16,135 is connected
# cell at 16,136 is connected
# cell at 16,137 is connected
# cell at 17,18 is connected
# cell at 17,19 is connected
# cell at 17,20 is connected
# cell at 17,26 is connected
# cell at 17,27 is connected
# cell at 17,28 is connected
# cell at 17,32 is connected
# cell at 17,33 is connected
# cell at 17,34 is connected
# cell at 17,49 is connected
# cell at 17,50 is connected
# cell at 17,51 is connected
# cell at 17,57 is connected
# cell at 17,58 is connected
# cell at 17,59 is connected
# cell at 17,74 is connected
# cell at 17,75 is connected
# cell at 17,76 is connected
# cell at 17,81 is connected
# cell at 17,82 is connected
# cell at 17,83 is connected
# cell at 17,96 is connected
# cell at 17,97 is connected
# cell at 17,98 is connected
# cell at 17,117 is connected
# cell at 17,118 is connected
# cell at 17,119 is connected
# cell at 17,127 is connected
# cell at 17,128 is connected
# cell at 17,129 is connected
# cell at 17,132 is connected
# cell at 17,133 is connected
# cell at 17,134 is connected
# cell at 18,6 is connected
# cell at 18,7 is connected
# cell at 18,8 is connected
# cell at 18,14 is connected
# cell at 18,15 is connected
# cell at 18,16 is connected
# cell at 18,18 is connected
# cell at 18,19 is connected
# cell at 18,20 is connected
# cell at 18,21 is connected
# cell at 18,22 is connected
# cell at 18,33 is connected
# cell at 18,34 is connected
# cell at 18,35 is connected
# cell at 18,57 is connected
# cell at 18,58 is connected
# cell at 18,59 is connected
# cell at 18,60 is connected
# cell at 18,61 is connected
# cell at 18,72 is connected
# cell at 18,73 is connected
# cell at 18,74 is connected
# cell at 18,92 is connected
# cell at 18,93 is connected
# cell at 18,94 is connected
# cell at 18,96 is connected
# cell at 18,97 is connected
# cell at 18,98 is connected
# cell at 18,104 is connected
# cell at 18,105 is connected
# cell at 18,106 is connected
# cell at 18,117 is connected
# cell at 18,118 is connected
# cell at 18,119 is connected
# cell at 18,127 is connected
# cell at 18,128 is connected
# cell at 18,129 is connected
# cell at 18,132 is connected
# cell at 18,133 is connected
# cell at 18,134 is connected
# cell at 19,6 is connected
# cell at 19,7 is connected
# cell at 19,8 is connected
# cell at 19,14 is connected
# cell at 19,15 is connected
# cell at 19,16 is connected
# cell at 19,20 is connected
# cell at 19,21 is connected
# cell at 19,22 is connected
# cell at 19,33 is connected
# cell at 19,34 is connected
# cell at 19,35 is connected
# cell at 19,49 is connected
# cell at 19,50 is connected
# cell at 19,51 is connected
# cell at 19,57 is connected
# cell at 19,58 is connected
# cell at 19,59 is connected
# cell at 19,60 is connected
# cell at 19,61 is connected
# cell at 19,72 is connected
# cell at 19,73 is connected
# cell at 19,74 is connected
# cell at 19,86 is connected
# cell at 19,87 is connected
# cell at 19,88 is connected
# cell at 19,92 is connected
# cell at 19,93 is connected
# cell at 19,94 is connected
# cell at 19,96 is connected
# cell at 19,97 is connected
# cell at 19,98 is connected
# cell at 19,104 is connected
# cell at 19,105 is connected
# cell at 19,106 is connected
# cell at 19,110 is connected
# cell at 19,111 is connected
# cell at 19,112 is connected
# cell at 19,128 is connected
# cell at 19,129 is connected
# cell at 19,130 is connected
# cell at 19,132 is connected
# cell at 19,133 is connected
# cell at 19,134 is connected
# cell at 20,6 is connected
# cell at 20,7 is connected
# cell at 20,8 is connected
# cell at 20,14 is connected
# cell at 20,15 is connected
# cell at 20,16 is connected
# cell at 20,20 is connected
# cell at 20,21 is connected
# cell at 20,22 is connected
# cell at 20,23 is connected
# cell at 20,24 is connected
# cell at 20,29 is connected
# cell at 20,30 is connected
# cell at 20,31 is connected
# cell at 20,33 is connected
# cell at 20,34 is connected
# cell at 20,35 is connected
# cell at 20,49 is connected
# cell at 20,50 is connected
# cell at 20,51 is connected
# cell at 20,52 is connected
# cell at 20,53 is connected
# cell at 20,59 is connected
# cell at 20,60 is connected
# cell at 20,61 is connected
# cell at 20,69 is connected
# cell at 20,70 is connected
# cell at 20,71 is connected
# cell at 20,72 is connected
# cell at 20,73 is connected
# cell at 20,74 is connected
# cell at 20,79 is connected
# cell at 20,80 is connected
# cell at 20,81 is connected
# cell at 20,86 is connected
# cell at 20,87 is connected
# cell at 20,88 is connected
# cell at 20,92 is connected
# cell at 20,93 is connected
# cell at 20,94 is connected
# cell at 20,104 is connected
# cell at 20,105 is connected
# cell at 20,106 is connected
# cell at 20,110 is connected
# cell at 20,111 is connected
# cell at 20,112 is connected
# cell at 20,128 is connected
# cell at 20,129 is connected
# cell at 20,130 is connected
# cell at 20,135 is connected
# cell at 20,136 is connected
# cell at 20,137 is connected
# cell at 21,8 is connected
# cell at 21,9 is connected
# cell at 21,10 is connected
# cell at 21,22 is connected
# cell at 21,23 is connected
# cell at 21,24 is connected
# cell at 21,29 is connected
# cell at 21,30 is connected
# cell at 21,31 is connected
# cell at 21,42 is connected
# cell at 21,43 is connected
# cell at 21,44 is connected
# cell at 21,49 is connected
# cell at 21,50 is connected
# cell at 21,51 is connected
# cell at 21,52 is connected
# cell at 21,53 is connected
# cell at 21,69 is connected
# cell at 21,70 is connected
# cell at 21,71 is connected
# cell at 21,79 is connected
# cell at 21,80 is connected
# cell at 21,81 is connected
# cell at 21,86 is connected
# cell at 21,87 is connected
# cell at 21,88 is connected
# cell at 21,110 is connected
# cell at 21,111 is connected
# cell at 21,112 is connected
# cell at 21,113 is connected
# cell at 21,114 is connected
# cell at 21,119 is connected
# cell at 21,120 is connected
# cell at 21,121 is connected
# cell at 21,128 is connected
# cell at 21,129 is connected
# cell at 21,130 is connected
# cell at 21,135 is connected
# cell at 21,136 is connected
# cell at 21,137 is connected
# cell at 22,2 is connected
# cell at 22,3 is connected
# cell at 22,4 is connected
# cell at 22,8 is connected
# cell at 22,9 is connected
# cell at 22,10 is connected
# cell at 22,22 is connected
# cell at 22,23 is connected
# cell at 22,24 is connected
# cell at 22,29 is connected
# cell at 22,30 is connected
# cell at 22,31 is connected
# cell at 22,34 is connected
# cell at 22,35 is connected
# cell at 22,36 is connected
# cell at 22,42 is connected
# cell at 22,43 is connected
# cell at 22,44 is connected
# cell at 22,50 is connected
# cell at 22,51 is connected
# cell at 22,52 is connected
# cell at 22,53 is connected
# cell at 22,69 is connected
# cell at 22,70 is connected
# cell at 22,71 is connected
# cell at 22,75 is connected
# cell at 22,76 is connected
# cell at 22,77 is connected
# cell at 22,79 is connected
# cell at 22,80 is connected
# cell at 22,81 is connected
# cell at 22,87 is connected
# cell at 22,88 is connected
# cell at 22,89 is connected
# cell at 22,95 is connected
# cell at 22,96 is connected
# cell at 22,97 is connected
# cell at 22,108 is connected
# cell at 22,109 is connected
# cell at 22,110 is connected
# cell at 22,112 is connected
# cell at 22,113 is connected
# cell at 22,114 is connected
# cell at 22,119 is connected
# cell at 22,120 is connected
# cell at 22,121 is connected
# cell at 22,122 is connected
# cell at 22,123 is connected
# cell at 22,135 is connected
# cell at 22,136 is connected
# cell at 22,137 is connected
# cell at 23,2 is connected
# cell at 23,3 is connected
# cell at 23,4 is connected
# cell at 23,8 is connected
# cell at 23,9 is connected
# cell at 23,10 is connected
# cell at 23,34 is connected
# cell at 23,35 is connected
# cell at 23,36 is connected
# cell at 23,42 is connected
# cell at 23,43 is connected
# cell at 23,44 is connected
# cell at 23,50 is connected
# cell at 23,51 is connected
# cell at 23,52 is connected
# cell at 23,57 is connected
# cell at 23,58 is connected
# cell at 23,59 is connected
# cell at 23,62 is connected
# cell at 23,63 is connected
# cell at 23,64 is connected
# cell at 23,67 is connected
# cell at 23,68 is connected
# cell at 23,69 is connected
# cell at 23,75 is connected
# cell at 23,76 is connected
# cell at 23,77 is connected
# cell at 23,87 is connected
# cell at 23,88 is connected
# cell at 23,89 is connected
# cell at 23,95 is connected
# cell at 23,96 is connected
# cell at 23,97 is connected
# cell at 23,98 is connected
# cell at 23,99 is connected
# cell at 23,100 is connected
# cell at 23,108 is connected
# cell at 23,109 is connected
# cell at 23,110 is connected
# cell at 23,112 is connected
# cell at 23,113 is connected
# cell at 23,114 is connected
# cell at 23,119 is connected
# cell at 23,120 is connected
# cell at 23,121 is connected
# cell at 23,122 is connected
# cell at 23,123 is connected
# cell at 23,125 is connected
# cell at 23,126 is connected
# cell at 23,127 is connected
# cell at 23,129 is connected
# cell at 23,130 is connected
# cell at 23,131 is connected
# cell at 24,2 is connected
# cell at 24,3 is connected
# cell at 24,4 is connected
# cell at 24,34 is connected
# cell at 24,35 is connected
# cell at 24,36 is connected
# cell at 24,50 is connected
# cell at 24,51 is connected
# cell at 24,52 is connected
# cell at 24,57 is connected
# cell at 24,58 is connected
# cell at 24,59 is connected
# cell at 24,62 is connected
# cell at 24,63 is connected
# cell at 24,64 is connected
# cell at 24,67 is connected
# cell at 24,68 is connected
# cell at 24,69 is connected
# cell at 24,75 is connected
# cell at 24,76 is connected
# cell at 24,77 is connected
# cell at 24,87 is connected
# cell at 24,88 is connected
# cell at 24,89 is connected
# cell at 24,95 is connected
# cell at 24,96 is connected
# cell at 24,97 is connected
# cell at 24,98 is connected
# cell at 24,99 is connected
# cell at 24,100 is connected
# cell at 24,106 is connected
# cell at 24,107 is connected
# cell at 24,108 is connected
# cell at 24,109 is connected
# cell at 24,110 is connected
# cell at 24,121 is connected
# cell at 24,122 is connected
# cell at 24,123 is connected
# cell at 24,125 is connected
# cell at 24,126 is connected
# cell at 24,127 is connected
# cell at 24,129 is connected
# cell at 24,130 is connected
# cell at 24,131 is connected
# cell at 25,4 is connected
# cell at 25,5 is connected
# cell at 25,6 is connected
# cell at 25,27 is connected
# cell at 25,28 is connected
# cell at 25,29 is connected
# cell at 25,57 is connected
# cell at 25,58 is connected
# cell at 25,59 is connected
# cell at 25,62 is connected
# cell at 25,63 is connected
# cell at 25,64 is connected
# cell at 25,67 is connected
# cell at 25,68 is connected
# cell at 25,69 is connected
# cell at 25,83 is connected
# cell at 25,84 is connected
# cell at 25,85 is connected
# cell at 25,86 is connected
# cell at 25,87 is connected
# cell at 25,98 is connected
# cell at 25,99 is connected
# cell at 25,100 is connected
# cell at 25,101 is connected
# cell at 25,102 is connected
# cell at 25,103 is connected
# cell at 25,106 is connected
# cell at 25,107 is connected
# cell at 25,108 is connected
# cell at 25,125 is connected
# cell at 25,126 is connected
# cell at 25,127 is connected
# cell at 25,129 is connected
# cell at 25,130 is connected
# cell at 25,131 is connected
# cell at 26,2 is connected
# cell at 26,3 is connected
# cell at 26,4 is connected
# cell at 26,5 is connected
# cell at 26,6 is connected
# cell at 26,27 is connected
# cell at 26,28 is connected
# cell at 26,29 is connected
# cell at 26,31 is connected
# cell at 26,32 is connected
# cell at 26,33 is connected
# cell at 26,48 is connected
# cell at 26,49 is connected
# cell at 26,50 is connected
# cell at 26,60 is connected
# cell at 26,61 is connected
# cell at 26,62 is connected
# cell at 26,67 is connected
# cell at 26,68 is connected
# cell at 26,69 is connected
# cell at 26,83 is connected
# cell at 26,84 is connected
# cell at 26,85 is connected
# cell at 26,86 is connected
# cell at 26,87 is connected
# cell at 26,90 is connected
# cell at 26,91 is connected
# cell at 26,92 is connected
# cell at 26,101 is connected
# cell at 26,102 is connected
# cell at 26,103 is connected
# cell at 26,106 is connected
# cell at 26,107 is connected
# cell at 26,108 is connected
# cell at 26,125 is connected
# cell at 26,126 is connected
# cell at 26,127 is connected
# cell at 26,135 is connected
# cell at 26,136 is connected
# cell at 26,137 is connected
# cell at 27,2 is connected
# cell at 27,3 is connected
# cell at 27,4 is connected
# cell at 27,5 is connected
# cell at 27,6 is connected
# cell at 27,27 is connected
# cell at 27,28 is connected
# cell at 27,29 is connected
# cell at 27,31 is connected
# cell at 27,32 is connected
# cell at 27,33 is connected
# cell at 27,41 is connected
# cell at 27,42 is connected
# cell at 27,43 is connected
# cell at 27,48 is connected
# cell at 27,49 is connected
# cell at 27,50 is connected
# cell at 27,60 is connected
# cell at 27,61 is connected
# cell at 27,62 is connected
# cell at 27,67 is connected
# cell at 27,68 is connected
# cell at 27,69 is connected
# cell at 27,70 is connected
# cell at 27,71 is connected
# cell at 27,83 is connected
# cell at 27,84 is connected
# cell at 27,85 is connected
# cell at 27,86 is connected
# cell at 27,87 is connected
# cell at 27,90 is connected
# cell at 27,91 is connected
# cell at 27,92 is connected
# cell at 27,101 is connected
# cell at 27,102 is connected
# cell at 27,103 is connected
# cell at 27,105 is connected
# cell at 27,106 is connected
# cell at 27,107 is connected
# cell at 27,125 is connected
# cell at 27,126 is connected
# cell at 27,127 is connected
# cell at 27,135 is connected
# cell at 27,136 is connected
# cell at 27,137 is connected
# cell at 28,2 is connected
# cell at 28,3 is connected
# cell at 28,4 is connected
# cell at 28,28 is connected
# cell at 28,29 is connected
# cell at 28,30 is connected
# cell at 28,31 is connected
# cell at 28,32 is connected
# cell at 28,33 is connected
# cell at 28,39 is connected
# cell at 28,40 is connected
# cell at 28,41 is connected
# cell at 28,42 is connected
# cell at 28,43 is connected
# cell at 28,48 is connected
# cell at 28,49 is connected
# cell at 28,50 is connected
# cell at 28,60 is connected
# cell at 28,61 is connected
# cell at 28,62 is connected
# cell at 28,67 is connected
# cell at 28,68 is connected
# cell at 28,69 is connected
# cell at 28,70 is connected
# cell at 28,71 is connected
# cell at 28,90 is connected
# cell at 28,91 is connected
# cell at 28,92 is connected
# cell at 28,94 is connected
# cell at 28,95 is connected
# cell at 28,96 is connected
# cell at 28,100 is connected
# cell at 28,101 is connected
# cell at 28,102 is connected
# cell at 28,105 is connected
# cell at 28,106 is connected
# cell at 28,107 is connected
# cell at 28,113 is connected
# cell at 28,114 is connected
# cell at 28,115 is connected
# cell at 28,117 is connected
# cell at 28,118 is connected
# cell at 28,119 is connected
# cell at 28,125 is connected
# cell at 28,126 is connected
# cell at 28,127 is connected
# cell at 28,133 is connected
# cell at 28,134 is connected
# cell at 28,135 is connected
# cell at 28,136 is connected
# cell at 28,137 is connected
# cell at 29,28 is connected
# cell at 29,29 is connected
# cell at 29,30 is connected
# cell at 29,33 is connected
# cell at 29,34 is connected
# cell at 29,35 is connected
# cell at 29,39 is connected
# cell at 29,40 is connected
# cell at 29,41 is connected
# cell at 29,42 is connected
# cell at 29,43 is connected
# cell at 29,69 is connected
# cell at 29,70 is connected
# cell at 29,71 is connected
# cell at 29,76 is connected
# cell at 29,77 is connected
# cell at 29,78 is connected
# cell at 29,94 is connected
# cell at 29,95 is connected
# cell at 29,96 is connected
# cell at 29,100 is connected
# cell at 29,101 is connected
# cell at 29,102 is connected
# cell at 29,105 is connected
# cell at 29,106 is connected
# cell at 29,107 is connected
# cell at 29,113 is connected
# cell at 29,114 is connected
# cell at 29,115 is connected
# cell at 29,117 is connected
# cell at 29,118 is connected
# cell at 29,119 is connected
# cell at 29,120 is connected
# cell at 29,121 is connected
# cell at 29,131 is connected
# cell at 29,132 is connected
# cell at 29,133 is connected
# cell at 29,134 is connected
# cell at 29,135 is connected
# cell at 30,22 is connected
# cell at 30,23 is connected
# cell at 30,24 is connected
# cell at 30,28 is connected
# cell at 30,29 is connected
# cell at 30,30 is connected
# cell at 30,33 is connected
# cell at 30,34 is connected
# cell at 30,35 is connected
# cell at 30,39 is connected
# cell at 30,40 is connected
# cell at 30,41 is connected
# cell at 30,76 is connected
# cell at 30,77 is connected
# cell at 30,78 is connected
# cell at 30,89 is connected
# cell at 30,90 is connected
# cell at 30,91 is connected
# cell at 30,94 is connected
# cell at 30,95 is connected
# cell at 30,96 is connected
# cell at 30,97 is connected
# cell at 30,98 is connected
# cell at 30,99 is connected
# cell at 30,100 is connected
# cell at 30,101 is connected
# cell at 30,102 is connected
# cell at 30,104 is connected
# cell at 30,105 is connected
# cell at 30,106 is connected
# cell at 30,113 is connected
# cell at 30,114 is connected
# cell at 30,115 is connected
# cell at 30,117 is connected
# cell at 30,118 is connected
# cell at 30,119 is connected
# cell at 30,120 is connected
# cell at 30,121 is connected
# cell at 30,131 is connected
# cell at 30,132 is connected
# cell at 30,133 is connected
# cell at 30,134 is connected
# cell at 30,135 is connected
# cell at 31,7 is connected
# cell at 31,8 is connected
# cell at 31,9 is connected
# cell at 31,22 is connected
# cell at 31,23 is connected
# cell at 31,24 is connected
# cell at 31,33 is connected
# cell at 31,34 is connected
# cell at 31,35 is connected
# cell at 31,49 is connected
# cell at 31,50 is connected
# cell at 31,51 is connected
# cell at 31,53 is connected
# cell at 31,54 is connected
# cell at 31,55 is connected
# cell at 31,64 is connected
# cell at 31,65 is connected
# cell at 31,66 is connected
# cell at 31,70 is connected
# cell at 31,71 is connected
# cell at 31,72 is connected
# cell at 31,76 is connected
# cell at 31,77 is connected
# cell at 31,78 is connected
# cell at 31,89 is connected
# cell at 31,90 is connected
# cell at 31,91 is connected
# cell at 31,97 is connected
# cell at 31,98 is connected
# cell at 31,99 is connected
# cell at 31,102 is connected
# cell at 31,103 is connected
# cell at 31,104 is connected
# cell at 31,105 is connected
# cell at 31,106 is connected
# cell at 31,119 is connected
# cell at 31,120 is connected
# cell at 31,121 is connected
# cell at 31,131 is connected
# cell at 31,132 is connected
# cell at 31,133 is connected
# cell at 32,7 is connected
# cell at 32,8 is connected
# cell at 32,9 is connected
# cell at 32,22 is connected
# cell at 32,23 is connected
# cell at 32,24 is connected
# cell at 32,26 is connected
# cell at 32,27 is connected
# cell at 32,28 is connected
# cell at 32,40 is connected
# cell at 32,41 is connected
# cell at 32,42 is connected
# cell at 32,49 is connected
# cell at 32,50 is connected
# cell at 32,51 is connected
# cell at 32,53 is connected
# cell at 32,54 is connected
# cell at 32,55 is connected
# cell at 32,64 is connected
# cell at 32,65 is connected
# cell at 32,66 is connected
# cell at 32,70 is connected
# cell at 32,71 is connected
# cell at 32,72 is connected
# cell at 32,77 is connected
# cell at 32,78 is connected
# cell at 32,79 is connected
# cell at 32,84 is connected
# cell at 32,85 is connected
# cell at 32,86 is connected
# cell at 32,89 is connected
# cell at 32,90 is connected
# cell at 32,91 is connected
# cell at 32,97 is connected
# cell at 32,98 is connected
# cell at 32,99 is connected
# cell at 32,102 is connected
# cell at 32,103 is connected
# cell at 32,104 is connected
# cell at 32,105 is connected
# cell at 32,106 is connected
# cell at 32,124 is connected
# cell at 32,125 is connected
# cell at 32,126 is connected
# cell at 32,129 is connected
# cell at 32,130 is connected
# cell at 32,131 is connected
# cell at 33,2 is connected
# cell at 33,3 is connected
# cell at 33,4 is connected
# cell at 33,7 is connected
# cell at 33,8 is connected
# cell at 33,9 is connected
# cell at 33,13 is connected
# cell at 33,14 is connected
# cell at 33,15 is connected
# cell at 33,26 is connected
# cell at 33,27 is connected
# cell at 33,28 is connected
# cell at 33,40 is connected
# cell at 33,41 is connected
# cell at 33,42 is connected
# cell at 33,49 is connected
# cell at 33,50 is connected
# cell at 33,51 is connected
# cell at 33,53 is connected
# cell at 33,54 is connected
# cell at 33,55 is connected
# cell at 33,64 is connected
# cell at 33,65 is connected
# cell at 33,66 is connected
# cell at 33,70 is connected
# cell at 33,71 is connected
# cell at 33,72 is connected
# cell at 33,77 is connected
# cell at 33,78 is connected
# cell at 33,79 is connected
# cell at 33,84 is connected
# cell at 33,85 is connected
# cell at 33,86 is connected
# cell at 33,98 is connected
# cell at 33,99 is connected
# cell at 33,100 is connected
# cell at 33,102 is connected
# cell at 33,103 is connected
# cell at 33,104 is connected
# cell at 33,116 is connected
# cell at 33,117 is connected
# cell at 33,118 is connected
# cell at 33,124 is connected
# cell at 33,125 is connected
# cell at 33,126 is connected
# cell at 33,129 is connected
# cell at 33,130 is connected
# cell at 33,131 is connected
# cell at 34,2 is connected
# cell at 34,3 is connected
# cell at 34,4 is connected
# cell at 34,5 is connected
# cell at 34,6 is connected
# cell at 34,13 is connected
# cell at 34,14 is connected
# cell at 34,15 is connected
# cell at 34,26 is connected
# cell at 34,27 is connected
# cell at 34,28 is connected
# cell at 34,40 is connected
# cell at 34,41 is connected
# cell at 34,42 is connected
# cell at 34,44 is connected
# cell at 34,45 is connected
# cell at 34,46 is connected
# cell at 34,72 is connected
# cell at 34,73 is connected
# cell at 34,74 is connected
# cell at 34,77 is connected
# cell at 34,78 is connected
# cell at 34,79 is connected
# cell at 34,84 is connected
# cell at 34,85 is connected
# cell at 34,86 is connected
# cell at 34,98 is connected
# cell at 34,99 is connected
# cell at 34,100 is connected
# cell at 34,107 is connected
# cell at 34,108 is connected
# cell at 34,109 is connected
# cell at 34,116 is connected
# cell at 34,117 is connected
# cell at 34,118 is connected
# cell at 34,122 is connected
# cell at 34,123 is connected
# cell at 34,124 is connected
# cell at 34,125 is connected
# cell at 34,126 is connected
# cell at 34,129 is connected
# cell at 34,130 is connected
# cell at 34,131 is connected
# cell at 35,2 is connected
# cell at 35,3 is connected
# cell at 35,4 is connected
# cell at 35,5 is connected
# cell at 35,6 is connected
# cell at 35,13 is connected
# cell at 35,14 is connected
# cell at 35,15 is connected
# cell at 35,16 is connected
# cell at 35,17 is connected
# cell at 35,18 is connected
# cell at 35,26 is connected
# cell at 35,27 is connected
# cell at 35,28 is connected
# cell at 35,31 is connected
# cell at 35,32 is connected
# cell at 35,33 is connected
# cell at 35,35 is connected
# cell at 35,36 is connected
# cell at 35,37 is connected
# cell at 35,44 is connected
# cell at 35,45 is connected
# cell at 35,46 is connected
# cell at 35,57 is connected
# cell at 35,58 is connected
# cell at 35,59 is connected
# cell at 35,67 is connected
# cell at 35,68 is connected
# cell at 35,69 is connected
# cell at 35,72 is connected
# cell at 35,73 is connected
# cell at 35,74 is connected
# cell at 35,80 is connected
# cell at 35,81 is connected
# cell at 35,82 is connected
# cell at 35,98 is connected
# cell at 35,99 is connected
# cell at 35,100 is connected
# cell at 35,107 is connected
# cell at 35,108 is connected
# cell at 35,109 is connected
# cell at 35,116 is connected
# cell at 35,117 is connected
# cell at 35,118 is connected
# cell at 35,122 is connected
# cell at 35,123 is connected
# cell at 35,124 is connected
# cell at 35,131 is connected
# cell at 35,132 is connected
# cell at 35,133 is connected
# cell at 36,4 is connected
# cell at 36,5 is connected
# cell at 36,6 is connected
# cell at 36,7 is connected
# cell at 36,8 is connected
# cell at 36,9 is connected
# cell at 36,10 is connected
# cell at 36,11 is connected
# cell at 36,16 is connected
# cell at 36,17 is connected
# cell at 36,18 is connected
# cell at 36,20 is connected
# cell at 36,21 is connected
# cell at 36,22 is connected
# cell at 36,26 is connected
# cell at 36,27 is connected
# cell at 36,28 is connected
# cell at 36,31 is connected
# cell at 36,32 is connected
# cell at 36,33 is connected
# cell at 36,35 is connected
# cell at 36,36 is connected
# cell at 36,37 is connected
# cell at 36,41 is connected
# cell at 36,42 is connected
# cell at 36,43 is connected
# cell at 36,44 is connected
# cell at 36,45 is connected
# cell at 36,46 is connected
# cell at 36,57 is connected
# cell at 36,58 is connected
# cell at 36,59 is connected
# cell at 36,63 is connected
# cell at 36,64 is connected
# cell at 36,65 is connected
# cell at 36,67 is connected
# cell at 36,68 is connected
# cell at 36,69 is connected
# cell at 36,72 is connected
# cell at 36,73 is connected
# cell at 36,74 is connected
# cell at 36,80 is connected
# cell at 36,81 is connected
# cell at 36,82 is connected
# cell at 36,89 is connected
# cell at 36,90 is connected
# cell at 36,91 is connected
# cell at 36,107 is connected
# cell at 36,108 is connected
# cell at 36,109 is connected
# cell at 36,115 is connected
# cell at 36,116 is connected
# cell at 36,117 is connected
# cell at 36,122 is connected
# cell at 36,123 is connected
# cell at 36,124 is connected
# cell at 36,131 is connected
# cell at 36,132 is connected
# cell at 36,133 is connected
# cell at 36,134 is connected
# cell at 36,135 is connected
# cell at 36,136 is connected
# cell at 37,7 is connected
# cell at 37,8 is connected
# cell at 37,9 is connected
# cell at 37,10 is connected
# cell at 37,11 is connected
# cell at 37,16 is connected
# cell at 37,17 is connected
# cell at 37,18 is connected
# cell at 37,20 is connected
# cell at 37,21 is connected
# cell at 37,22 is connected
# cell at 37,26 is connected
# cell at 37,27 is connected
# cell at 37,28 is connected
# cell at 37,31 is connected
# cell at 37,32 is connected
# cell at 37,33 is connected
# cell at 37,35 is connected
# cell at 37,36 is connected
# cell at 37,37 is connected
# cell at 37,41 is connected
# cell at 37,42 is connected
# cell at 37,43 is connected
# cell at 37,54 is connected
# cell at 37,55 is connected
# cell at 37,56 is connected
# cell at 37,57 is connected
# cell at 37,58 is connected
# cell at 37,59 is connected
# cell at 37,63 is connected
# cell at 37,64 is connected
# cell at 37,65 is connected
# cell at 37,67 is connected
# cell at 37,68 is connected
# cell at 37,69 is connected
# cell at 37,80 is connected
# cell at 37,81 is connected
# cell at 37,82 is connected
# cell at 37,89 is connected
# cell at 37,90 is connected
# cell at 37,91 is connected
# cell at 37,115 is connected
# cell at 37,116 is connected
# cell at 37,117 is connected
# cell at 37,131 is connected
# cell at 37,132 is connected
# cell at 37,133 is connected
# cell at 37,134 is connected
# cell at 37,135 is connected
# cell at 37,136 is connected
# cell at 38,7 is connected
# cell at 38,8 is connected
# cell at 38,9 is connected
# cell at 38,10 is connected
# cell at 38,11 is connected
# cell at 38,20 is connected
# cell at 38,21 is connected
# cell at 38,22 is connected
# cell at 38,26 is connected
# cell at 38,27 is connected
# cell at 38,28 is connected
# cell at 38,41 is connected
# cell at 38,42 is connected
# cell at 38,43 is connected
# cell at 38,54 is connected
# cell at 38,55 is connected
# cell at 38,56 is connected
# cell at 38,63 is connected
# cell at 38,64 is connected
# cell at 38,65 is connected
# cell at 38,72 is connected
# cell at 38,73 is connected
# cell at 38,74 is connected
# cell at 38,89 is connected
# cell at 38,90 is connected
# cell at 38,91 is connected
# cell at 38,93 is connected
# cell at 38,94 is connected
# cell at 38,95 is connected
# cell at 38,115 is connected
# cell at 38,116 is connected
# cell at 38,117 is connected
# cell at 38,126 is connected
# cell at 38,127 is connected
# cell at 38,128 is connected
# cell at 38,133 is connected
# cell at 38,134 is connected
# cell at 38,135 is connected
# cell at 38,136 is connected
# cell at 39,9 is connected
# cell at 39,10 is connected
# cell at 39,11 is connected
# cell at 39,16 is connected
# cell at 39,17 is connected
# cell at 39,18 is connected
# cell at 39,26 is connected
# cell at 39,27 is connected
# cell at 39,28 is connected
# cell at 39,38 is connected
# cell at 39,39 is connected
# cell at 39,40 is connected
# cell at 39,45 is connected
# cell at 39,46 is connected
# cell at 39,47 is connected
# cell at 39,54 is connected
# cell at 39,55 is connected
# cell at 39,56 is connected
# cell at 39,59 is connected
# cell at 39,60 is connected
# cell at 39,61 is connected
# cell at 39,72 is connected
# cell at 39,73 is connected
# cell at 39,74 is connected
# cell at 39,75 is connected
# cell at 39,76 is connected
# cell at 39,79 is connected
# cell at 39,80 is connected
# cell at 39,81 is connected
# cell at 39,93 is connected
# cell at 39,94 is connected
# cell at 39,95 is connected
# cell at 39,104 is connected
# cell at 39,105 is connected
# cell at 39,106 is connected
# cell at 39,113 is connected
# ...
# 545
# continuing from 545
# 810
# continuing from 810
# 868
# continuing from 868
# 217
# continuing from 217
# 479
# continuing from 479
# 725
# continuing from 725
# 802
# continuing from 802
# 409
# 29
# continuing from 29
# 74
# continuing from 74
# 341
# continuing from 341
# continuing from 566
# 433
# continuing from 433
# 149
# continuing from 149
# 331
# continuing from 331
# 998
# continuing from 998
# 171
# continuing from 171
# 90
# continuing from 90
# 28
# 704
# continuing from 704
# 959
# continuing from 959
# 504
# continuing from 504
# 684
# continuing from 684
# 705
# continuing from 705
# 476
# continuing from 476
# 4
# continuing from 4
# 939
# continuing from 939
# 252
# continuing from 252
# 26
# continuing from 26
# 519
# continuing from 519
# 994
# continuing from 994
# 855
# continuing from 855
# 572
# continuing from 572
# 699
# continuing from 699
# 942
# continuing from 942
# 997
# continuing from 997
# 562
# continuing from 562
# 67
# 991
# continuing from 991
# 764
# continuing from 764
# 692
# continuing from 692
# 368
# continuing from 368
# 151
# continuing from 151
# 847
# continuing from 847
# 959
# continuing from 959
# 9
# continuing from 9
# 782
# continuing from 782
# 892
# continuing from 892
# 188
# continuing from 188
# 399
# continuing from 399
# 739
# continuing from 739
# 208
# 928
# 729
# 721
# continuing from 721
# 577
# continuing from 577
# 144
# continuing from 144
# 906
# continuing from 906
# 864
# continuing from 864
# 416
# continuing from 416
# 45
# 73
# 388
# continuing from 388
# 689
# continuing from 689
# 11
# 546563

# %%
# day 3 part 2
with open('puzzle_input.txt', 'r') as f:
    data = [x.strip('\n').strip(' ') for x in f.readlines()]

# import string
import re
# from collections import defaultdict


    # all symbols except for `.`
symbols = ['*']
# symbols.remove('.')


class Node:
    def __init__(self, rownum, colnum, value):
        self.rownum = rownum
        self.colnum = colnum
        self.value = value
        self.connected = False
        self.is_gear = False
        self.connected_integers = []

        pass
    
    def __repr__(self):
        return f"{self.value} at {self.rownum, self.colnum}"


all_nodes = []

for rownum, row in enumerate(data):
    thisrow = []
    #current = None
    for colnum, column in enumerate(row):
        current = Node(rownum, colnum, data[rownum][colnum])
        thisrow.append(current)
    all_nodes.append(thisrow)

all_gears = []

for rownum, row in enumerate(all_nodes):
    for colnum, cell in enumerate(row):
        if cell.value in symbols:
            cell.connected=True
            cell.is_gear=True
            all_gears.append(cell)


            ## add the connected indexes
            for i in range(cell.rownum-1, cell.rownum+2):
                for j in range(cell.colnum-1, cell.colnum+2):
                    try:
                        all_nodes[i][j].connected = True
                    except:
                        print('error') # no symbols are out of bounds?? crazy
                        print('out of bounds for row {i} column {j}')
# all_nodes.__len__(), [x.__len__() for x in all_nodes]

# for row in all_nodes:
#     print([True if x.connected == True else None for x in row])

for cell in all_gears:
    connected_to_gear = []
    # print(f"searching for connected elements to gear at {cell}")

    for i in (-1, 0, +1):
        row = data[cell.rownum+i]
        matches = re.finditer('\d+', row)
        # print(f"matches for row {cell.rownum+i}")
        for m in matches:
            # print(m)
            for index in list(range(*m.span())):
                if index in range(cell.colnum-1, cell.colnum+2):
                    connected_to_gear.append(m.group())
                    break
                
            
        
    cell.connected_integers = connected_to_gear
    print(cell, connected_to_gear)




total_value = 0
for gear in all_gears:
    if len(gear.connected_integers) == 2:
        total_value += int(gear.connected_integers[0]) * int(gear.connected_integers[1])

total_value

#91031374 is correct
